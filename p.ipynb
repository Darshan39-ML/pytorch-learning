# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot

# %%
X, y = make_classification(n_samples=9000, n_features= 18, n_informative= 4, n_redundant= 12, random_state= 4)

# %%
X_train, y_train, X_test, y_test = train_test_split(x, y, train_size= 0.3)

# %%
train_score, test_score = list(), list()

# %%
values = [i for i in range(1,21)]

# %%
for i in values:
    model = DecisionTreeClassifier(max_depth= i)
    model.fit(X_train, y_train)
    train_yhat = model.predict(X_train)
    train_acc = accuracy_score(y_train, train_yhat)
    test_yhat = model.predict(X_test)
    test_acc = accuracy_score(y_test, test_yhat)

print(train_acc, test_acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 for i in values:
#       2     model = DecisionTreeClassifier(max_depth= i)
# ----> 3     model.fit(X_train, y_train)
#       4     train_yhat = model.predict(X_train)
#       5     train_acc = accuracy_score(y_train, train_yhat)
#       6     test_yhat = model.predict(X_test)
#
# File ~/code-for-darshan/Pytorch-Learning-For-Me/pytorch-learning/myenv/lib/python3.12/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/code-for-darshan/Pytorch-Learning-For-Me/pytorch-learning/myenv/lib/python3.12/site-packages/sklearn/tree/_classes.py:1018, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     987 @_fit_context(prefer_skip_nested_validation=True)
#     988 def fit(self, X, y, sample_weight=None, check_input=True):
#     989     """Build a decision tree classifier from the training set (X, y).
#     990
#     991     Parameters
#    (...)   1015         Fitted estimator.
#    1016     """
# -> 1018     super()._fit(
#    1019         X,
#    1020         y,
#    1021         sample_weight=sample_weight,
#    1022         check_input=check_input,
#    1023     )
#    1024     return self
#
# File ~/code-for-darshan/Pytorch-Learning-For-Me/pytorch-learning/myenv/lib/python3.12/site-packages/sklearn/tree/_classes.py:289, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     286 self.n_outputs_ = y.shape[1]
#     288 if is_classification:
# --> 289     check_classification_targets(y)
#     290     y = np.copy(y)
#     292     self.classes_ = []
#
# File ~/code-for-darshan/Pytorch-Learning-For-Me/pytorch-learning/myenv/lib/python3.12/site-packages/sklearn/utils/multiclass.py:230, in check_classification_targets(y)
#     222 y_type = type_of_target(y, input_name="y")
#     223 if y_type not in [
#     224     "binary",
#     225     "multiclass",
#    (...)    228     "multilabel-sequences",
#     229 ]:
# --> 230     raise ValueError(
#     231         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     232         "classifier, which expects discrete classes on a "
#     233         "regression target with continuous values."
#     234     )
#     236 if "multiclass" in y_type:
#     237     n_samples = _num_samples(y)
#
# ValueError: Unknown label type: continuous-multioutput. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
