# %%
import torch
print(torch.__version__)
# Out:
# 2.13.0+cu130

# %%
gpu_available=torch.cuda.is_available()
print("the cuda",{is_gpu_available})
# Out:
# the cuda {True}

# %%
if gpu_available:
    # Get details about the active GPU
    print(f"Active GPU ID: {torch.cuda.current_device()}")
    print(f"Active GPU Name: {torch.cuda.get_device_name(0)}")

# 2. Activate the GPU device dynamically (Device-agnostic setup)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}\n")

# 3. Verify activation by moving a tensor to the GPU
# Create a sample tensor on the CPU
x = torch.rand(3, 3)
print(f"Original tensor device: {x.device}")

# Move the tensor to the activated device
x = x.to(device)
print(f"Moved tensor device: {x.device}")
# Out:
# Active GPU ID: 0
# Active GPU Name: NVIDIA GeForce RTX 4050 Laptop GPU
# Using device: cuda
#
# Original tensor device: cpu
# Moved tensor device: cuda:0
